# %% [markdown]
# # Map, Filter, Reduce, Lambda & Recursion

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Lambda Functions</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Saving to a Variable <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Multiple Inputs <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Passing a Lambda into a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Returning a Lambda from a Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) In-Class Exercise #1 <br>
# 2) <b>Map</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Map <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #2 <br>
# 3) <b>Filter</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Filter <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #3 <br>
# 4) <b>Reduce</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Using Lambda's with Reduce <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #4 <br>
# 5) <b>Recursion</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Implementing a Base <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Writing a Factorial Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #5 <br>
# 6) <b>Generators & Iterators</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Yield Keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Inifinite Generator <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #6 <br>
# 7) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Filtering Empty Strings <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Exercise #2 - Sorting with Last Name <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Exercise #3 - Conversion to Farhenheit <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Exercise #4 - Fibonacci Sequence <br>

# %% [markdown]
# ## Lambda Functions <br>
# <p>Lambda functions... or "Anonymous Functions" are referring to inline functions with no name. The keyword lambda denotes the no name function, and executes within a single line. Without saving it to a variable; however, it is not able to be used, unless passed in either as a paramater or within list comprehension.<br>Written as "(keyword lambda) (one or more inputs) (colon) (function to be executed)"</p>

# %% [markdown]
# #### Syntax

# %%
def add_two(x): #function
    return x+2
print(add_two(3)) # represent lambda
print(add_two)

# lambda function.
lambda x: x+2 # function

(lambda x: x+2)(3)
# Out:
# 5
# 5

# %% [markdown]
# #### Saving to a Variable

# %%
f = lambda x,y : x+y+2
(lambda x,y : x+y+2)(2,3)
f(2,3)
# Out:
# 7

# %% [markdown]
# #### Multiple Inputs

# %%
(lambda x,y,z : x*y*z)(3,5,8)
three_multiply = lambda x,y,z : x*y*z
three_multiply(3,5,8)
# Out:
# 120

# %% [markdown]
# #### Passing a Lambda into a Function

# %%
def muliply(f,num):
    return f(num)
muliply(lambda x: x*x, 4)
# Out:
# 16

# %% [markdown]
# #### Returning a Lambda from a Function

# %%
def return_func(): # if using a parameter
    def multiply(num):
        return num*num
    return multiply
# return_func() represents muliply
return_func()(5)  # "name" parameter

def return_lamb(b,c):
    return lambda x,a: x+a+b+c

return_lamb(2,4)(5,7)
# Out:
# 18

# %% [markdown]
# #### If Statements within Lambdas

# %%
#Lambda x : True if (condition) else false
f = lambda num : num*2 if num > 10 else num + 2

f(10)
f(12)
# Out:
# 24

# %% [markdown]
# #### In-Class Exercise #1 <br>
# <p>Write an anonymous function that cubes the arguments passed in and assign the anonymous function to a variable 'f'.</p>

# %%
f = lambda cube : cube**3
f(3)
# Out:
# 27

# %%
#get good at reading Documentation because this is your lifelinealso
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
sorted([2,7,3486,2446,647,45778], reverse=True)
# Out:
# [45778, 3486, 2446, 647, 7, 2]

# %%
j ={
    "name": "jesus",
    "age": 8
}
t = {
    "name": "tate",
    "age": 18
}
m = {
    "name": "McCall",
    "age": 23
}
a = {
    "name": "Anu",
    "age": 97
}

people = [m,j,a,t]
print(people)
# lambda function must return the value you want to sort on
my_lamb = lambda person_dict: person_dict["age"]
print(sorted(people, key = my_lambda))

print(sorted(people, key = lambda person_dict: person_dict["age"])) # for person_dict in person_dict
print(sorted(people, key = lambda person_dict: person_dict["age"], reverse=True))
# Out:
# [{'name': 'McCall', 'age': 23}, {'name': 'jesus', 'age': 8}, {'name': 'Anu', 'age': 97}, {'name': 'tate', 'age': 18}]
# [{'name': 'jesus', 'age': 8}, {'name': 'tate', 'age': 18}, {'name': 'McCall', 'age': 23}, {'name': 'Anu', 'age': 97}]
# [{'name': 'Anu', 'age': 97}, {'name': 'McCall', 'age': 23}, {'name': 'tate', 'age': 18}, {'name': 'jesus', 'age': 8}]

# %%
#Using Lambdas with sort to sort a list of dictionary by a key from highest to smallest

# %% [markdown]
# ## Map <br>
# <p>The map function allows you to iterate over an entire list while running a function on each item of the list. This is why the map function works well with lambda's, because it simplifies things and you write less lines of code.<br>The syntax for a map function is "map(function to be used, list to be used)"<br>However, you must be careful, as the map function returns a map object, not a list. To turn it into a list we use the list() type conversion.</p>

# %% [markdown]
# #### Syntax

# %%
# map(func,iterable(list,dict,tuple,set,etc...))
# Normally the usage of map happens with a pre-defined function -- but can use lambdas as well
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
def squared(num, num2):
    if num <10 and num2 <10:
        return num**2, num2**2
    else:
        return num, num2
    
numbers = [4,10,3,2,6]
more_nums = [4,11,20,3,15]
squared_nums_map = map (squared,numbers,more_nums)
list(squared_nums_map)
# Out:
# [(16, 16), (10, 11), (3, 20), (4, 9), (6, 15)]

# %%
numbers = [4,10,3,2,6]
squared_nums = list(map(lambda x: x**2 if x<10 else x, numbers))
squared_nums
# Out:
# [16, 10, 9, 4, 36]

# %% [markdown]
# #### Using Lambda's with Map

# %%
squared_num2 = list(map(lambda x1, y1: (x1**2, y1**2) if x1 < 10 and y1 <10 else (x1,y1),numbers,more_nums))
squared_num2
# Out:
# [(16, 16), (10, 11), (3, 20), (4, 9), (6, 15)]

# %% [markdown]
# #### In-Class Exercise #2 <br>
# <p>Use the map function to double each number and minus it by one in the list by using a lambda function</p>

# %%
nums = [4,2,6,8]

dub_minus_one = list(map(lambda x: (x*2)-1, nums))
dub_minus_one
# Out:
# [7, 3, 11, 15]

# %% [markdown]
# ## Filter() <br>
# <p>Filter's are similar to the map function, where you're able to pass a function argument and a list argument and filter out something from the list based on the conditions passed. Similar to the map function, it returns a filter object, so you need to type convert it to a list()</p>

# %% [markdown]
# #### Syntax

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function or None, iterable) --> filter object
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# filter the list for first names starting with T
names = ["Jesus","Tim","Christina","Eduardo","David", "Tate"]

def t_names(name):
    if name[0].lower() == "t":
        return True
    else:
        return False
new_names_list = filter(t_names, names)    
list(new_names_list)
# Out:
# ['Tim', 'Tate']

# %% [markdown]
# #### Using Lambda's with Filter()

# %%
new_names_lamb = list(filter(lambda name: True if name[0].lower() == "t" else False, names))
new_names_lamb
# Out:
# ['Tim', 'Tate']

# %% [markdown]
# #### In-Class Exercise #3 <br>
# <p>Filter out all the numbers that are below the mean of the list.<br><b>Hint: Import the 'statistics' module</b></p>

# %%
from statistics import mean
mean([1,2,3])
# Out:
# 2

# %% [markdown]
# ## Reduce() <br>
# <p>Be very careful when using this function, as of Python 3 it's been moved to the 'functools' library and no longer is a built-in function.<br>The creator of Python himself, says to just use a for loop instead.</p>

# %% [markdown]
# #### Syntax

# %%
from functools import reduce
# reduce(function,iterable)
help(reduce)
# Out:
# Help on built-in function reduce in module _functools:
#
# reduce(...)
#     reduce(function, sequence[, initial]) -> value
#
#     Apply a function of two arguments cumulatively to the items of a sequence,
#     from left to right, so as to reduce the sequence to a single value.
#     For example, reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates
#     ((((1+2)+3)+4)+5).  If initial is present, it is placed before the items
#     of the sequence in the calculation, and serves as a default when the
#     sequence is empty.

# %%
list_1 = [2,4,6,8,10]

def subtract_nums(num1, num2):
    return num1 - num2
result = reduce(subtract_nums, list_1)
result
# Out:
# -26

# %% [markdown]
# #### Using Lambda's with Reduce()

# %%
l_3 = [1,10,2,30]
result_lamb = reduce(lambda x,y : x-y, l_3)
result_lamb
# Out:
# -41

# %% [markdown]
# #### In-Class Exercise #4 <br>
# <p>Use the reduce function to multiply the numbers in the list below together with a lambda function.</p>

# %%
l_5 = [1,2,3,4]

multi_lamb = reduce(lambda x,y : x*y, l_5)
multi_lamb
# Out:
# 24

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a35b8a9a3903> in <module>
# ----> 1 multi_lamb = reduce(lambda x,y : x*y, l_5)
#       2 multi_lamb
#
# NameError: name 'l_5' is not defined

# %% [markdown]
# ## Recursion <br>
# <p>Recursion means that a function is calling itself, so it contanstly executes until a base case is reached. It will then push the returning values back up the chain until the function is complete. A prime example of recursion is computing factorials... such that 5! (factorial) is 5*4*3*2*1 which equals 120.</p>

# %%
def recursive(i):
    print("Hi")
    if i == 4:
        return
    i+=1
    recursive(i)
    
recursive(0)
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi

# %% [markdown]
# #### Implementing a Base Case

# %%
def add_nums(num):
    # set base case
    if num <= 1:
        print("add_nums(1)=1")
        return num
    else:
        print(f"add_num({num}) = {num} + add_nums({num -1})")
        return num + add_nums(num-1)
add_nums(5)
# Out:
# add_num(5) = 5 + add_nums(4)
# add_num(4) = 4 + add_nums(3)
# add_num(3) = 3 + add_nums(2)
# add_num(2) = 2 + add_nums(1)
# add_nums(1)=1
# 15

# %% [markdown]
# #### Writing a Factorial Function

# %%
# 5! = 5*4*3*2*1
def factorial(num):
    # set base case
    if num <= 1:
        return 1
    else:
        print(f"factorial({num}) = {num} + factorial({num-1})")
        return num * factorial(num-1)
factorial(5000)
# Out:
# factorial(5000) = 5000 + factorial(4999)
# factorial(4999) = 4999 + factorial(4998)
# factorial(4998) = 4998 + factorial(4997)
# factorial(4997) = 4997 + factorial(4996)
# factorial(4996) = 4996 + factorial(4995)
# factorial(4995) = 4995 + factorial(4994)
# factorial(4994) = 4994 + factorial(4993)
# factorial(4993) = 4993 + factorial(4992)
# factorial(4992) = 4992 + factorial(4991)
# factorial(4991) = 4991 + factorial(4990)
# factorial(4990) = 4990 + factorial(4989)
# factorial(4989) = 4989 + factorial(4988)
# factorial(4988) = 4988 + factorial(4987)
# factorial(4987) = 4987 + factorial(4986)
# factorial(4986) = 4986 + factorial(4985)
# factorial(4985) = 4985 + factorial(4984)
# factorial(4984) = 4984 + factorial(4983)
# factorial(4983) = 4983 + factorial(4982)
# factorial(4982) = 4982 + factorial(4981)
# factorial(4981) = 4981 + factorial(4980)
# factorial(4980) = 4980 + factorial(4979)
# factorial(4979) = 4979 + factorial(4978)
# factorial(4978) = 4978 + factorial(4977)
# factorial(4977) = 4977 + factorial(4976)
# factorial(4976) = 4976 + factorial(4975)
# factorial(4975) = 4975 + factorial(4974)
# factorial(4974) = 4974 + factorial(4973)
# factorial(4973) = 4973 + factorial(4972)
# factorial(4972) = 4972 + factorial(4971)
# factorial(4971) = 4971 + factorial(4970)
# factorial(4970) = 4970 + factorial(4969)
# factorial(4969) = 4969 + factorial(4968)
# factorial(4968) = 4968 + factorial(4967)
# factorial(4967) = 4967 + factorial(4966)
# factorial(4966) = 4966 + factorial(4965)
# factorial(4965) = 4965 + factorial(4964)
# factorial(4964) = 4964 + factorial(4963)
# factorial(4963) = 4963 + factorial(4962)
# factorial(4962) = 4962 + factorial(4961)
# factorial(4961) = 4961 + factorial(4960)
# factorial(4960) = 4960 + factorial(4959)
# factorial(4959) = 4959 + factorial(4958)
# factorial(4958) = 4958 + factorial(4957)
# factorial(4957) = 4957 + factorial(4956)
# factorial(4956) = 4956 + factorial(4955)
# factorial(4955) = 4955 + factorial(4954)
# factorial(4954) = 4954 + factorial(4953)
# factorial(4953) = 4953 + factorial(4952)
# factorial(4952) = 4952 + factorial(4951)
# factorial(4951) = 4951 + factorial(4950)
# factorial(4950) = 4950 + factorial(4949)
# factorial(4949) = 4949 + factorial(4948)
# factorial(4948) = 4948 + factorial(4947)
# factorial(4947) = 4947 + factorial(4946)
# factorial(4946) = 4946 + factorial(4945)
# factorial(4945) = 4945 + factorial(4944)
# factorial(4944) = 4944 + factorial(4943)
# factorial(4943) = 4943 + factorial(4942)
# factorial(4942) = 4942 + factorial(4941)
# factorial(4941) = 4941 + factorial(4940)
# factorial(4940) = 4940 + factorial(4939)
# factorial(4939) = 4939 + factorial(4938)
# factorial(4938) = 4938 + factorial(4937)
# factorial(4937) = 4937 + factorial(4936)
# factorial(4936) = 4936 + factorial(4935)
# factorial(4935) = 4935 + factorial(4934)
# factorial(4934) = 4934 + factorial(4933)
# factorial(4933) = 4933 + factorial(4932)
# factorial(4932) = 4932 + factorial(4931)
# factorial(4931) = 4931 + factorial(4930)
# factorial(4930) = 4930 + factorial(4929)
# factorial(4929) = 4929 + factorial(4928)
# factorial(4928) = 4928 + factorial(4927)
# factorial(4927) = 4927 + factorial(4926)
# factorial(4926) = 4926 + factorial(4925)
# factorial(4925) = 4925 + factorial(4924)
# factorial(4924) = 4924 + factorial(4923)
# factorial(4923) = 4923 + factorial(4922)
# factorial(4922) = 4922 + factorial(4921)
# factorial(4921) = 4921 + factorial(4920)
# factorial(4920) = 4920 + factorial(4919)
# factorial(4919) = 4919 + factorial(4918)
# factorial(4918) = 4918 + factorial(4917)
# factorial(4917) = 4917 + factorial(4916)
# factorial(4916) = 4916 + factorial(4915)
# factorial(4915) = 4915 + factorial(4914)
# factorial(4914) = 4914 + factorial(4913)
# factorial(4913) = 4913 + factorial(4912)
# factorial(4912) = 4912 + factorial(4911)
# factorial(4911) = 4911 + factorial(4910)
# factorial(4910) = 4910 + factorial(4909)
# factorial(4909) = 4909 + factorial(4908)
# factorial(4908) = 4908 + factorial(4907)
# factorial(4907) = 4907 + factorial(4906)
# factorial(4906) = 4906 + factorial(4905)
# factorial(4905) = 4905 + factorial(4904)
# factorial(4904) = 4904 + factorial(4903)
# factorial(4903) = 4903 + factorial(4902)
# factorial(4902) = 4902 + factorial(4901)
# factorial(4901) = 4901 + factorial(4900)
# factorial(4900) = 4900 + factorial(4899)
# factorial(4899) = 4899 + factorial(4898)
# factorial(4898) = 4898 + factorial(4897)
# factorial(4897) = 4897 + factorial(4896)
# factorial(4896) = 4896 + factorial(4895)
# factorial(4895) = 4895 + factorial(4894)
# factorial(4894) = 4894 + factorial(4893)
# factorial(4893) = 4893 + factorial(4892)
# factorial(4892) = 4892 + factorial(4891)
# factorial(4891) = 4891 + factorial(4890)
# factorial(4890) = 4890 + factorial(4889)
# factorial(4889) = 4889 + factorial(4888)
# factorial(4888) = 4888 + factorial(4887)
# factorial(4887) = 4887 + factorial(4886)
# factorial(4886) = 4886 + factorial(4885)
# factorial(4885) = 4885 + factorial(4884)
# factorial(4884) = 4884 + factorial(4883)
# factorial(4883) = 4883 + factorial(4882)
# factorial(4882) = 4882 + factorial(4881)
# factorial(4881) = 4881 + factorial(4880)
# factorial(4880) = 4880 + factorial(4879)
# factorial(4879) = 4879 + factorial(4878)
# factorial(4878) = 4878 + factorial(4877)
# factorial(4877) = 4877 + factorial(4876)
# factorial(4876) = 4876 + factorial(4875)
# factorial(4875) = 4875 + factorial(4874)
# factorial(4874) = 4874 + factorial(4873)
# factorial(4873) = 4873 + factorial(4872)
# factorial(4872) = 4872 + factorial(4871)
# factorial(4871) = 4871 + factorial(4870)
# factorial(4870) = 4870 + factorial(4869)
# factorial(4869) = 4869 + factorial(4868)
# factorial(4868) = 4868 + factorial(4867)
# factorial(4867) = 4867 + factorial(4866)
# factorial(4866) = 4866 + factorial(4865)
# factorial(4865) = 4865 + factorial(4864)
# factorial(4864) = 4864 + factorial(4863)
# factorial(4863) = 4863 + factorial(4862)
# factorial(4862) = 4862 + factorial(4861)
# factorial(4861) = 4861 + factorial(4860)
# factorial(4860) = 4860 + factorial(4859)
# factorial(4859) = 4859 + factorial(4858)
# factorial(4858) = 4858 + factorial(4857)
# factorial(4857) = 4857 + factorial(4856)
# factorial(4856) = 4856 + factorial(4855)
# factorial(4855) = 4855 + factorial(4854)
# factorial(4854) = 4854 + factorial(4853)
# factorial(4853) = 4853 + factorial(4852)
# factorial(4852) = 4852 + factorial(4851)
# factorial(4851) = 4851 + factorial(4850)
# factorial(4850) = 4850 + factorial(4849)
# factorial(4849) = 4849 + factorial(4848)
# factorial(4848) = 4848 + factorial(4847)
# factorial(4847) = 4847 + factorial(4846)
# factorial(4846) = 4846 + factorial(4845)
# factorial(4845) = 4845 + factorial(4844)
# factorial(4844) = 4844 + factorial(4843)
# factorial(4843) = 4843 + factorial(4842)
# factorial(4842) = 4842 + factorial(4841)
# factorial(4841) = 4841 + factorial(4840)
# factorial(4840) = 4840 + factorial(4839)
# factorial(4839) = 4839 + factorial(4838)
# factorial(4838) = 4838 + factorial(4837)
# factorial(4837) = 4837 + factorial(4836)
# factorial(4836) = 4836 + factorial(4835)
# factorial(4835) = 4835 + factorial(4834)
# factorial(4834) = 4834 + factorial(4833)
# factorial(4833) = 4833 + factorial(4832)
# factorial(4832) = 4832 + factorial(4831)
# factorial(4831) = 4831 + factorial(4830)
# factorial(4830) = 4830 + factorial(4829)
# factorial(4829) = 4829 + factorial(4828)
# factorial(4828) = 4828 + factorial(4827)
# factorial(4827) = 4827 + factorial(4826)
# factorial(4826) = 4826 + factorial(4825)
# factorial(4825) = 4825 + factorial(4824)
# factorial(4824) = 4824 + factorial(4823)
# factorial(4823) = 4823 + factorial(4822)
# factorial(4822) = 4822 + factorial(4821)
# factorial(4821) = 4821 + factorial(4820)
# factorial(4820) = 4820 + factorial(4819)
# factorial(4819) = 4819 + factorial(4818)
# factorial(4818) = 4818 + factorial(4817)
# factorial(4817) = 4817 + factorial(4816)
# factorial(4816) = 4816 + factorial(4815)
# factorial(4815) = 4815 + factorial(4814)
# factorial(4814) = 4814 + factorial(4813)
# factorial(4813) = 4813 + factorial(4812)
# factorial(4812) = 4812 + factorial(4811)
# factorial(4811) = 4811 + factorial(4810)
# factorial(4810) = 4810 + factorial(4809)
# factorial(4809) = 4809 + factorial(4808)
# factorial(4808) = 4808 + factorial(4807)
# factorial(4807) = 4807 + factorial(4806)
# factorial(4806) = 4806 + factorial(4805)
# factorial(4805) = 4805 + factorial(4804)
# factorial(4804) = 4804 + factorial(4803)
# factorial(4803) = 4803 + factorial(4802)
# factorial(4802) = 4802 + factorial(4801)
# factorial(4801) = 4801 + factorial(4800)
# factorial(4800) = 4800 + factorial(4799)
# factorial(4799) = 4799 + factorial(4798)
# factorial(4798) = 4798 + factorial(4797)
# factorial(4797) = 4797 + factorial(4796)
# factorial(4796) = 4796 + factorial(4795)
# factorial(4795) = 4795 + factorial(4794)
# factorial(4794) = 4794 + factorial(4793)
# factorial(4793) = 4793 + factorial(4792)
# factorial(4792) = 4792 + factorial(4791)
# factorial(4791) = 4791 + factorial(4790)
# factorial(4790) = 4790 + factorial(4789)
# factorial(4789) = 4789 + factorial(4788)
# factorial(4788) = 4788 + factorial(4787)
# factorial(4787) = 4787 + factorial(4786)
# factorial(4786) = 4786 + factorial(4785)
# factorial(4785) = 4785 + factorial(4784)
# factorial(4784) = 4784 + factorial(4783)
# factorial(4783) = 4783 + factorial(4782)
# factorial(4782) = 4782 + factorial(4781)
# factorial(4781) = 4781 + factorial(4780)
# factorial(4780) = 4780 + factorial(4779)
# factorial(4779) = 4779 + factorial(4778)
# factorial(4778) = 4778 + factorial(4777)
# factorial(4777) = 4777 + factorial(4776)
# factorial(4776) = 4776 + factorial(4775)
# factorial(4775) = 4775 + factorial(4774)
# factorial(4774) = 4774 + factorial(4773)
# factorial(4773) = 4773 + factorial(4772)
# factorial(4772) = 4772 + factorial(4771)
# factorial(4771) = 4771 + factorial(4770)
# factorial(4770) = 4770 + factorial(4769)
# factorial(4769) = 4769 + factorial(4768)
# factorial(4768) = 4768 + factorial(4767)
# factorial(4767) = 4767 + factorial(4766)
# factorial(4766) = 4766 + factorial(4765)
# factorial(4765) = 4765 + factorial(4764)
# factorial(4764) = 4764 + factorial(4763)
# factorial(4763) = 4763 + factorial(4762)
# factorial(4762) = 4762 + factorial(4761)
# factorial(4761) = 4761 + factorial(4760)
# factorial(4760) = 4760 + factorial(4759)
# factorial(4759) = 4759 + factorial(4758)
# factorial(4758) = 4758 + factorial(4757)
# factorial(4757) = 4757 + factorial(4756)
# factorial(4756) = 4756 + factorial(4755)
# factorial(4755) = 4755 + factorial(4754)
# factorial(4754) = 4754 + factorial(4753)
# factorial(4753) = 4753 + factorial(4752)
# factorial(4752) = 4752 + factorial(4751)
# factorial(4751) = 4751 + factorial(4750)
# factorial(4750) = 4750 + factorial(4749)
# factorial(4749) = 4749 + factorial(4748)
# factorial(4748) = 4748 + factorial(4747)
# factorial(4747) = 4747 + factorial(4746)
# factorial(4746) = 4746 + factorial(4745)
# factorial(4745) = 4745 + factorial(4744)
# factorial(4744) = 4744 + factorial(4743)
# factorial(4743) = 4743 + factorial(4742)
# factorial(4742) = 4742 + factorial(4741)
# factorial(4741) = 4741 + factorial(4740)
# factorial(4740) = 4740 + factorial(4739)
# factorial(4739) = 4739 + factorial(4738)
# factorial(4738) = 4738 + factorial(4737)
# factorial(4737) = 4737 + factorial(4736)
# factorial(4736) = 4736 + factorial(4735)
# factorial(4735) = 4735 + factorial(4734)
# factorial(4734) = 4734 + factorial(4733)
# factorial(4733) = 4733 + factorial(4732)
# factorial(4732) = 4732 + factorial(4731)
# factorial(4731) = 4731 + factorial(4730)
# factorial(4730) = 4730 + factorial(4729)
# factorial(4729) = 4729 + factorial(4728)
# factorial(4728) = 4728 + factorial(4727)
# factorial(4727) = 4727 + factorial(4726)
# factorial(4726) = 4726 + factorial(4725)
# factorial(4725) = 4725 + factorial(4724)
# factorial(4724) = 4724 + factorial(4723)
# factorial(4723) = 4723 + factorial(4722)
# factorial(4722) = 4722 + factorial(4721)
# factorial(4721) = 4721 + factorial(4720)
# factorial(4720) = 4720 + factorial(4719)
# factorial(4719) = 4719 + factorial(4718)
# factorial(4718) = 4718 + factorial(4717)
# factorial(4717) = 4717 + factorial(4716)
# factorial(4716) = 4716 + factorial(4715)
# factorial(4715) = 4715 + factorial(4714)
# factorial(4714) = 4714 + factorial(4713)
# factorial(4713) = 4713 + factorial(4712)
# factorial(4712) = 4712 + factorial(4711)
# factorial(4711) = 4711 + factorial(4710)
# factorial(4710) = 4710 + factorial(4709)
# factorial(4709) = 4709 + factorial(4708)
# factorial(4708) = 4708 + factorial(4707)
# factorial(4707) = 4707 + factorial(4706)
# factorial(4706) = 4706 + factorial(4705)
# factorial(4705) = 4705 + factorial(4704)
# factorial(4704) = 4704 + factorial(4703)
# factorial(4703) = 4703 + factorial(4702)
# factorial(4702) = 4702 + factorial(4701)
# factorial(4701) = 4701 + factorial(4700)
# factorial(4700) = 4700 + factorial(4699)
# factorial(4699) = 4699 + factorial(4698)
# factorial(4698) = 4698 + factorial(4697)
# factorial(4697) = 4697 + factorial(4696)
# factorial(4696) = 4696 + factorial(4695)
# factorial(4695) = 4695 + factorial(4694)
# factorial(4694) = 4694 + factorial(4693)
# factorial(4693) = 4693 + factorial(4692)
# factorial(4692) = 4692 + factorial(4691)
# factorial(4691) = 4691 + factorial(4690)
# factorial(4690) = 4690 + factorial(4689)
# factorial(4689) = 4689 + factorial(4688)
# factorial(4688) = 4688 + factorial(4687)
# factorial(4687) = 4687 + factorial(4686)
# factorial(4686) = 4686 + factorial(4685)
# factorial(4685) = 4685 + factorial(4684)
# factorial(4684) = 4684 + factorial(4683)
# factorial(4683) = 4683 + factorial(4682)
# factorial(4682) = 4682 + factorial(4681)
# factorial(4681) = 4681 + factorial(4680)
# factorial(4680) = 4680 + factorial(4679)
# factorial(4679) = 4679 + factorial(4678)
# factorial(4678) = 4678 + factorial(4677)
# factorial(4677) = 4677 + factorial(4676)
# factorial(4676) = 4676 + factorial(4675)
# factorial(4675) = 4675 + factorial(4674)
# factorial(4674) = 4674 + factorial(4673)
# factorial(4673) = 4673 + factorial(4672)
# factorial(4672) = 4672 + factorial(4671)
# factorial(4671) = 4671 + factorial(4670)
# factorial(4670) = 4670 + factorial(4669)
# factorial(4669) = 4669 + factorial(4668)
# factorial(4668) = 4668 + factorial(4667)
# factorial(4667) = 4667 + factorial(4666)
# factorial(4666) = 4666 + factorial(4665)
# factorial(4665) = 4665 + factorial(4664)
# factorial(4664) = 4664 + factorial(4663)
# factorial(4663) = 4663 + factorial(4662)
# factorial(4662) = 4662 + factorial(4661)
# factorial(4661) = 4661 + factorial(4660)
# factorial(4660) = 4660 + factorial(4659)
# factorial(4659) = 4659 + factorial(4658)
# factorial(4658) = 4658 + factorial(4657)
# factorial(4657) = 4657 + factorial(4656)
# factorial(4656) = 4656 + factorial(4655)
# factorial(4655) = 4655 + factorial(4654)
# factorial(4654) = 4654 + factorial(4653)
# factorial(4653) = 4653 + factorial(4652)
# factorial(4652) = 4652 + factorial(4651)
# factorial(4651) = 4651 + factorial(4650)
# factorial(4650) = 4650 + factorial(4649)
# factorial(4649) = 4649 + factorial(4648)
# factorial(4648) = 4648 + factorial(4647)
# factorial(4647) = 4647 + factorial(4646)
# factorial(4646) = 4646 + factorial(4645)
# factorial(4645) = 4645 + factorial(4644)
# factorial(4644) = 4644 + factorial(4643)
# factorial(4643) = 4643 + factorial(4642)
# factorial(4642) = 4642 + factorial(4641)
# factorial(4641) = 4641 + factorial(4640)
# factorial(4640) = 4640 + factorial(4639)
# factorial(4639) = 4639 + factorial(4638)
# factorial(4638) = 4638 + factorial(4637)
# factorial(4637) = 4637 + factorial(4636)
# factorial(4636) = 4636 + factorial(4635)
# factorial(4635) = 4635 + factorial(4634)
# factorial(4634) = 4634 + factorial(4633)
# factorial(4633) = 4633 + factorial(4632)
# factorial(4632) = 4632 + factorial(4631)
# factorial(4631) = 4631 + factorial(4630)
# factorial(4630) = 4630 + factorial(4629)
# factorial(4629) = 4629 + factorial(4628)
# factorial(4628) = 4628 + factorial(4627)
# factorial(4627) = 4627 + factorial(4626)
# factorial(4626) = 4626 + factorial(4625)
# factorial(4625) = 4625 + factorial(4624)
# factorial(4624) = 4624 + factorial(4623)
# factorial(4623) = 4623 + factorial(4622)
# factorial(4622) = 4622 + factorial(4621)
# factorial(4621) = 4621 + factorial(4620)
# factorial(4620) = 4620 + factorial(4619)
# factorial(4619) = 4619 + factorial(4618)
# factorial(4618) = 4618 + factorial(4617)
# factorial(4617) = 4617 + factorial(4616)
# factorial(4616) = 4616 + factorial(4615)
# factorial(4615) = 4615 + factorial(4614)
# factorial(4614) = 4614 + factorial(4613)
# factorial(4613) = 4613 + factorial(4612)
# factorial(4612) = 4612 + factorial(4611)
# factorial(4611) = 4611 + factorial(4610)
# factorial(4610) = 4610 + factorial(4609)
# factorial(4609) = 4609 + factorial(4608)
# factorial(4608) = 4608 + factorial(4607)
# factorial(4607) = 4607 + factorial(4606)
# factorial(4606) = 4606 + factorial(4605)
# factorial(4605) = 4605 + factorial(4604)
# factorial(4604) = 4604 + factorial(4603)
# factorial(4603) = 4603 + factorial(4602)
# factorial(4602) = 4602 + factorial(4601)
# factorial(4601) = 4601 + factorial(4600)
# factorial(4600) = 4600 + factorial(4599)
# factorial(4599) = 4599 + factorial(4598)
# factorial(4598) = 4598 + factorial(4597)
# factorial(4597) = 4597 + factorial(4596)
# factorial(4596) = 4596 + factorial(4595)
# factorial(4595) = 4595 + factorial(4594)
# factorial(4594) = 4594 + factorial(4593)
# factorial(4593) = 4593 + factorial(4592)
# factorial(4592) = 4592 + factorial(4591)
# factorial(4591) = 4591 + factorial(4590)
# factorial(4590) = 4590 + factorial(4589)
# factorial(4589) = 4589 + factorial(4588)
# factorial(4588) = 4588 + factorial(4587)
# factorial(4587) = 4587 + factorial(4586)
# factorial(4586) = 4586 + factorial(4585)
# factorial(4585) = 4585 + factorial(4584)
# factorial(4584) = 4584 + factorial(4583)
# factorial(4583) = 4583 + factorial(4582)
# factorial(4582) = 4582 + factorial(4581)
# factorial(4581) = 4581 + factorial(4580)
# factorial(4580) = 4580 + factorial(4579)
# factorial(4579) = 4579 + factorial(4578)
# factorial(4578) = 4578 + factorial(4577)
# factorial(4577) = 4577 + factorial(4576)
# factorial(4576) = 4576 + factorial(4575)
# factorial(4575) = 4575 + factorial(4574)
# factorial(4574) = 4574 + factorial(4573)
# factorial(4573) = 4573 + factorial(4572)
# factorial(4572) = 4572 + factorial(4571)
# factorial(4571) = 4571 + factorial(4570)
# factorial(4570) = 4570 + factorial(4569)
# factorial(4569) = 4569 + factorial(4568)
# factorial(4568) = 4568 + factorial(4567)
# factorial(4567) = 4567 + factorial(4566)
# factorial(4566) = 4566 + factorial(4565)
# factorial(4565) = 4565 + factorial(4564)
# factorial(4564) = 4564 + factorial(4563)
# factorial(4563) = 4563 + factorial(4562)
# factorial(4562) = 4562 + factorial(4561)
# factorial(4561) = 4561 + factorial(4560)
# factorial(4560) = 4560 + factorial(4559)
# factorial(4559) = 4559 + factorial(4558)
# factorial(4558) = 4558 + factorial(4557)
# factorial(4557) = 4557 + factorial(4556)
# factorial(4556) = 4556 + factorial(4555)
# factorial(4555) = 4555 + factorial(4554)
# factorial(4554) = 4554 + factorial(4553)
# factorial(4553) = 4553 + factorial(4552)
# factorial(4552) = 4552 + factorial(4551)
# factorial(4551) = 4551 + factorial(4550)
# factorial(4550) = 4550 + factorial(4549)
# factorial(4549) = 4549 + factorial(4548)
# factorial(4548) = 4548 + factorial(4547)
# factorial(4547) = 4547 + factorial(4546)
# factorial(4546) = 4546 + factorial(4545)
# factorial(4545) = 4545 + factorial(4544)
# factorial(4544) = 4544 + factorial(4543)
# factorial(4543) = 4543 + factorial(4542)
# factorial(4542) = 4542 + factorial(4541)
# factorial(4541) = 4541 + factorial(4540)
# factorial(4540) = 4540 + factorial(4539)
# factorial(4539) = 4539 + factorial(4538)
# factorial(4538) = 4538 + factorial(4537)
# factorial(4537) = 4537 + factorial(4536)
# factorial(4536) = 4536 + factorial(4535)
# factorial(4535) = 4535 + factorial(4534)
# factorial(4534) = 4534 + factorial(4533)
# factorial(4533) = 4533 + factorial(4532)
# factorial(4532) = 4532 + factorial(4531)
# factorial(4531) = 4531 + factorial(4530)
# factorial(4530) = 4530 + factorial(4529)
# factorial(4529) = 4529 + factorial(4528)
# factorial(4528) = 4528 + factorial(4527)
# factorial(4527) = 4527 + factorial(4526)
# factorial(4526) = 4526 + factorial(4525)
# factorial(4525) = 4525 + factorial(4524)
# factorial(4524) = 4524 + factorial(4523)
# factorial(4523) = 4523 + factorial(4522)
# factorial(4522) = 4522 + factorial(4521)
# factorial(4521) = 4521 + factorial(4520)
# factorial(4520) = 4520 + factorial(4519)
# factorial(4519) = 4519 + factorial(4518)
# factorial(4518) = 4518 + factorial(4517)
# factorial(4517) = 4517 + factorial(4516)
# factorial(4516) = 4516 + factorial(4515)
# factorial(4515) = 4515 + factorial(4514)
# factorial(4514) = 4514 + factorial(4513)
# factorial(4513) = 4513 + factorial(4512)
# factorial(4512) = 4512 + factorial(4511)
# factorial(4511) = 4511 + factorial(4510)
# factorial(4510) = 4510 + factorial(4509)
# factorial(4509) = 4509 + factorial(4508)
# factorial(4508) = 4508 + factorial(4507)
# factorial(4507) = 4507 + factorial(4506)
# factorial(4506) = 4506 + factorial(4505)
# factorial(4505) = 4505 + factorial(4504)
# factorial(4504) = 4504 + factorial(4503)
# factorial(4503) = 4503 + factorial(4502)
# factorial(4502) = 4502 + factorial(4501)
# factorial(4501) = 4501 + factorial(4500)
# factorial(4500) = 4500 + factorial(4499)
# factorial(4499) = 4499 + factorial(4498)
# factorial(4498) = 4498 + factorial(4497)
# factorial(4497) = 4497 + factorial(4496)
# factorial(4496) = 4496 + factorial(4495)
# factorial(4495) = 4495 + factorial(4494)
# factorial(4494) = 4494 + factorial(4493)
# factorial(4493) = 4493 + factorial(4492)
# factorial(4492) = 4492 + factorial(4491)
# factorial(4491) = 4491 + factorial(4490)
# factorial(4490) = 4490 + factorial(4489)
# factorial(4489) = 4489 + factorial(4488)
# factorial(4488) = 4488 + factorial(4487)
# factorial(4487) = 4487 + factorial(4486)
# factorial(4486) = 4486 + factorial(4485)
# factorial(4485) = 4485 + factorial(4484)
# factorial(4484) = 4484 + factorial(4483)
# factorial(4483) = 4483 + factorial(4482)
# factorial(4482) = 4482 + factorial(4481)
# factorial(4481) = 4481 + factorial(4480)
# factorial(4480) = 4480 + factorial(4479)
# factorial(4479) = 4479 + factorial(4478)
# factorial(4478) = 4478 + factorial(4477)
# factorial(4477) = 4477 + factorial(4476)
# factorial(4476) = 4476 + factorial(4475)
# factorial(4475) = 4475 + factorial(4474)
# factorial(4474) = 4474 + factorial(4473)
# factorial(4473) = 4473 + factorial(4472)
# factorial(4472) = 4472 + factorial(4471)
# factorial(4471) = 4471 + factorial(4470)
# factorial(4470) = 4470 + factorial(4469)
# factorial(4469) = 4469 + factorial(4468)
# factorial(4468) = 4468 + factorial(4467)
# factorial(4467) = 4467 + factorial(4466)
# factorial(4466) = 4466 + factorial(4465)
# factorial(4465) = 4465 + factorial(4464)
# factorial(4464) = 4464 + factorial(4463)
# factorial(4463) = 4463 + factorial(4462)
# factorial(4462) = 4462 + factorial(4461)
# factorial(4461) = 4461 + factorial(4460)
# factorial(4460) = 4460 + factorial(4459)
# factorial(4459) = 4459 + factorial(4458)
# factorial(4458) = 4458 + factorial(4457)
# factorial(4457) = 4457 + factorial(4456)
# factorial(4456) = 4456 + factorial(4455)
# factorial(4455) = 4455 + factorial(4454)
# factorial(4454) = 4454 + factorial(4453)
# factorial(4453) = 4453 + factorial(4452)
# factorial(4452) = 4452 + factorial(4451)
# factorial(4451) = 4451 + factorial(4450)
# factorial(4450) = 4450 + factorial(4449)
# factorial(4449) = 4449 + factorial(4448)
# factorial(4448) = 4448 + factorial(4447)
# factorial(4447) = 4447 + factorial(4446)
# factorial(4446) = 4446 + factorial(4445)
# factorial(4445) = 4445 + factorial(4444)
# factorial(4444) = 4444 + factorial(4443)
# factorial(4443) = 4443 + factorial(4442)
# factorial(4442) = 4442 + factorial(4441)
# factorial(4441) = 4441 + factorial(4440)
# factorial(4440) = 4440 + factorial(4439)
# factorial(4439) = 4439 + factorial(4438)
# factorial(4438) = 4438 + factorial(4437)
# factorial(4437) = 4437 + factorial(4436)
# factorial(4436) = 4436 + factorial(4435)
# factorial(4435) = 4435 + factorial(4434)
# factorial(4434) = 4434 + factorial(4433)
# factorial(4433) = 4433 + factorial(4432)
# factorial(4432) = 4432 + factorial(4431)
# factorial(4431) = 4431 + factorial(4430)
# factorial(4430) = 4430 + factorial(4429)
# factorial(4429) = 4429 + factorial(4428)
# factorial(4428) = 4428 + factorial(4427)
# factorial(4427) = 4427 + factorial(4426)
# factorial(4426) = 4426 + factorial(4425)
# factorial(4425) = 4425 + factorial(4424)
# factorial(4424) = 4424 + factorial(4423)
# factorial(4423) = 4423 + factorial(4422)
# factorial(4422) = 4422 + factorial(4421)
# factorial(4421) = 4421 + factorial(4420)
# factorial(4420) = 4420 + factorial(4419)
# factorial(4419) = 4419 + factorial(4418)
# factorial(4418) = 4418 + factorial(4417)
# factorial(4417) = 4417 + factorial(4416)
# factorial(4416) = 4416 + factorial(4415)
# factorial(4415) = 4415 + factorial(4414)
# factorial(4414) = 4414 + factorial(4413)
# factorial(4413) = 4413 + factorial(4412)
# factorial(4412) = 4412 + factorial(4411)
# factorial(4411) = 4411 + factorial(4410)
# factorial(4410) = 4410 + factorial(4409)
# factorial(4409) = 4409 + factorial(4408)
# factorial(4408) = 4408 + factorial(4407)
# factorial(4407) = 4407 + factorial(4406)
# factorial(4406) = 4406 + factorial(4405)
# factorial(4405) = 4405 + factorial(4404)
# factorial(4404) = 4404 + factorial(4403)
# factorial(4403) = 4403 + factorial(4402)
# factorial(4402) = 4402 + factorial(4401)
# factorial(4401) = 4401 + factorial(4400)
# factorial(4400) = 4400 + factorial(4399)
# factorial(4399) = 4399 + factorial(4398)
# factorial(4398) = 4398 + factorial(4397)
# factorial(4397) = 4397 + factorial(4396)
# factorial(4396) = 4396 + factorial(4395)
# factorial(4395) = 4395 + factorial(4394)
# factorial(4394) = 4394 + factorial(4393)
# factorial(4393) = 4393 + factorial(4392)
# factorial(4392) = 4392 + factorial(4391)
# factorial(4391) = 4391 + factorial(4390)
# factorial(4390) = 4390 + factorial(4389)
# factorial(4389) = 4389 + factorial(4388)
# factorial(4388) = 4388 + factorial(4387)
# factorial(4387) = 4387 + factorial(4386)
# factorial(4386) = 4386 + factorial(4385)
# factorial(4385) = 4385 + factorial(4384)
# factorial(4384) = 4384 + factorial(4383)
# factorial(4383) = 4383 + factorial(4382)
# factorial(4382) = 4382 + factorial(4381)
# factorial(4381) = 4381 + factorial(4380)
# factorial(4380) = 4380 + factorial(4379)
# factorial(4379) = 4379 + factorial(4378)
# factorial(4378) = 4378 + factorial(4377)
# factorial(4377) = 4377 + factorial(4376)
# factorial(4376) = 4376 + factorial(4375)
# factorial(4375) = 4375 + factorial(4374)
# factorial(4374) = 4374 + factorial(4373)
# factorial(4373) = 4373 + factorial(4372)
# factorial(4372) = 4372 + factorial(4371)
# factorial(4371) = 4371 + factorial(4370)
# factorial(4370) = 4370 + factorial(4369)
# factorial(4369) = 4369 + factorial(4368)
# factorial(4368) = 4368 + factorial(4367)
# factorial(4367) = 4367 + factorial(4366)
# factorial(4366) = 4366 + factorial(4365)
# factorial(4365) = 4365 + factorial(4364)
# factorial(4364) = 4364 + factorial(4363)
# factorial(4363) = 4363 + factorial(4362)
# factorial(4362) = 4362 + factorial(4361)
# factorial(4361) = 4361 + factorial(4360)
# factorial(4360) = 4360 + factorial(4359)
# factorial(4359) = 4359 + factorial(4358)
# factorial(4358) = 4358 + factorial(4357)
# factorial(4357) = 4357 + factorial(4356)
# factorial(4356) = 4356 + factorial(4355)
# factorial(4355) = 4355 + factorial(4354)
# factorial(4354) = 4354 + factorial(4353)
# factorial(4353) = 4353 + factorial(4352)
# factorial(4352) = 4352 + factorial(4351)
# factorial(4351) = 4351 + factorial(4350)
# factorial(4350) = 4350 + factorial(4349)
# factorial(4349) = 4349 + factorial(4348)
# factorial(4348) = 4348 + factorial(4347)
# factorial(4347) = 4347 + factorial(4346)
# factorial(4346) = 4346 + factorial(4345)
# factorial(4345) = 4345 + factorial(4344)
# factorial(4344) = 4344 + factorial(4343)
# factorial(4343) = 4343 + factorial(4342)
# factorial(4342) = 4342 + factorial(4341)
# factorial(4341) = 4341 + factorial(4340)
# factorial(4340) = 4340 + factorial(4339)
# factorial(4339) = 4339 + factorial(4338)
# factorial(4338) = 4338 + factorial(4337)
# factorial(4337) = 4337 + factorial(4336)
# factorial(4336) = 4336 + factorial(4335)
# factorial(4335) = 4335 + factorial(4334)
# factorial(4334) = 4334 + factorial(4333)
# factorial(4333) = 4333 + factorial(4332)
# factorial(4332) = 4332 + factorial(4331)
# factorial(4331) = 4331 + factorial(4330)
# factorial(4330) = 4330 + factorial(4329)
# factorial(4329) = 4329 + factorial(4328)
# factorial(4328) = 4328 + factorial(4327)
# factorial(4327) = 4327 + factorial(4326)
# factorial(4326) = 4326 + factorial(4325)
# factorial(4325) = 4325 + factorial(4324)
# factorial(4324) = 4324 + factorial(4323)
# factorial(4323) = 4323 + factorial(4322)
# factorial(4322) = 4322 + factorial(4321)
# factorial(4321) = 4321 + factorial(4320)
# factorial(4320) = 4320 + factorial(4319)
# factorial(4319) = 4319 + factorial(4318)
# factorial(4318) = 4318 + factorial(4317)
# factorial(4317) = 4317 + factorial(4316)
# factorial(4316) = 4316 + factorial(4315)
# factorial(4315) = 4315 + factorial(4314)
# factorial(4314) = 4314 + factorial(4313)
# factorial(4313) = 4313 + factorial(4312)
# factorial(4312) = 4312 + factorial(4311)
# factorial(4311) = 4311 + factorial(4310)
# factorial(4310) = 4310 + factorial(4309)
# factorial(4309) = 4309 + factorial(4308)
# factorial(4308) = 4308 + factorial(4307)
# factorial(4307) = 4307 + factorial(4306)
# factorial(4306) = 4306 + factorial(4305)
# factorial(4305) = 4305 + factorial(4304)
# factorial(4304) = 4304 + factorial(4303)
# factorial(4303) = 4303 + factorial(4302)
# factorial(4302) = 4302 + factorial(4301)
# factorial(4301) = 4301 + factorial(4300)
# factorial(4300) = 4300 + factorial(4299)
# factorial(4299) = 4299 + factorial(4298)
# factorial(4298) = 4298 + factorial(4297)
# factorial(4297) = 4297 + factorial(4296)
# factorial(4296) = 4296 + factorial(4295)
# factorial(4295) = 4295 + factorial(4294)
# factorial(4294) = 4294 + factorial(4293)
# factorial(4293) = 4293 + factorial(4292)
# factorial(4292) = 4292 + factorial(4291)
# factorial(4291) = 4291 + factorial(4290)
# factorial(4290) = 4290 + factorial(4289)
# factorial(4289) = 4289 + factorial(4288)
# factorial(4288) = 4288 + factorial(4287)
# factorial(4287) = 4287 + factorial(4286)
# factorial(4286) = 4286 + factorial(4285)
# factorial(4285) = 4285 + factorial(4284)
# factorial(4284) = 4284 + factorial(4283)
# factorial(4283) = 4283 + factorial(4282)
# factorial(4282) = 4282 + factorial(4281)
# factorial(4281) = 4281 + factorial(4280)
# factorial(4280) = 4280 + factorial(4279)
# factorial(4279) = 4279 + factorial(4278)
# factorial(4278) = 4278 + factorial(4277)
# factorial(4277) = 4277 + factorial(4276)
# factorial(4276) = 4276 + factorial(4275)
# factorial(4275) = 4275 + factorial(4274)
# factorial(4274) = 4274 + factorial(4273)
# factorial(4273) = 4273 + factorial(4272)
# factorial(4272) = 4272 + factorial(4271)
# factorial(4271) = 4271 + factorial(4270)
# factorial(4270) = 4270 + factorial(4269)
# factorial(4269) = 4269 + factorial(4268)
# factorial(4268) = 4268 + factorial(4267)
# factorial(4267) = 4267 + factorial(4266)
# factorial(4266) = 4266 + factorial(4265)
# factorial(4265) = 4265 + factorial(4264)
# factorial(4264) = 4264 + factorial(4263)
# factorial(4263) = 4263 + factorial(4262)
# factorial(4262) = 4262 + factorial(4261)
# factorial(4261) = 4261 + factorial(4260)
# factorial(4260) = 4260 + factorial(4259)
# factorial(4259) = 4259 + factorial(4258)
# factorial(4258) = 4258 + factorial(4257)
# factorial(4257) = 4257 + factorial(4256)
# factorial(4256) = 4256 + factorial(4255)
# factorial(4255) = 4255 + factorial(4254)
# factorial(4254) = 4254 + factorial(4253)
# factorial(4253) = 4253 + factorial(4252)
# factorial(4252) = 4252 + factorial(4251)
# factorial(4251) = 4251 + factorial(4250)
# factorial(4250) = 4250 + factorial(4249)
# factorial(4249) = 4249 + factorial(4248)
# factorial(4248) = 4248 + factorial(4247)
# factorial(4247) = 4247 + factorial(4246)
# factorial(4246) = 4246 + factorial(4245)
# factorial(4245) = 4245 + factorial(4244)
# factorial(4244) = 4244 + factorial(4243)
# factorial(4243) = 4243 + factorial(4242)
# factorial(4242) = 4242 + factorial(4241)
# factorial(4241) = 4241 + factorial(4240)
# factorial(4240) = 4240 + factorial(4239)
# factorial(4239) = 4239 + factorial(4238)
# factorial(4238) = 4238 + factorial(4237)
# factorial(4237) = 4237 + factorial(4236)
# factorial(4236) = 4236 + factorial(4235)
# factorial(4235) = 4235 + factorial(4234)
# factorial(4234) = 4234 + factorial(4233)
# factorial(4233) = 4233 + factorial(4232)
# factorial(4232) = 4232 + factorial(4231)
# factorial(4231) = 4231 + factorial(4230)
# factorial(4230) = 4230 + factorial(4229)
# factorial(4229) = 4229 + factorial(4228)
# factorial(4228) = 4228 + factorial(4227)
# factorial(4227) = 4227 + factorial(4226)
# factorial(4226) = 4226 + factorial(4225)
# factorial(4225) = 4225 + factorial(4224)
# factorial(4224) = 4224 + factorial(4223)
# factorial(4223) = 4223 + factorial(4222)
# factorial(4222) = 4222 + factorial(4221)
# factorial(4221) = 4221 + factorial(4220)
# factorial(4220) = 4220 + factorial(4219)
# factorial(4219) = 4219 + factorial(4218)
# factorial(4218) = 4218 + factorial(4217)
# factorial(4217) = 4217 + factorial(4216)
# factorial(4216) = 4216 + factorial(4215)
# factorial(4215) = 4215 + factorial(4214)
# factorial(4214) = 4214 + factorial(4213)
# factorial(4213) = 4213 + factorial(4212)
# factorial(4212) = 4212 + factorial(4211)
# factorial(4211) = 4211 + factorial(4210)
# factorial(4210) = 4210 + factorial(4209)
# factorial(4209) = 4209 + factorial(4208)
# factorial(4208) = 4208 + factorial(4207)
# factorial(4207) = 4207 + factorial(4206)
# factorial(4206) = 4206 + factorial(4205)
# factorial(4205) = 4205 + factorial(4204)
# factorial(4204) = 4204 + factorial(4203)
# factorial(4203) = 4203 + factorial(4202)
# factorial(4202) = 4202 + factorial(4201)
# factorial(4201) = 4201 + factorial(4200)
# factorial(4200) = 4200 + factorial(4199)
# factorial(4199) = 4199 + factorial(4198)
# factorial(4198) = 4198 + factorial(4197)
# factorial(4197) = 4197 + factorial(4196)
# factorial(4196) = 4196 + factorial(4195)
# factorial(4195) = 4195 + factorial(4194)
# factorial(4194) = 4194 + factorial(4193)
# factorial(4193) = 4193 + factorial(4192)
# factorial(4192) = 4192 + factorial(4191)
# factorial(4191) = 4191 + factorial(4190)
# factorial(4190) = 4190 + factorial(4189)
# factorial(4189) = 4189 + factorial(4188)
# factorial(4188) = 4188 + factorial(4187)
# factorial(4187) = 4187 + factorial(4186)
# factorial(4186) = 4186 + factorial(4185)
# factorial(4185) = 4185 + factorial(4184)
# factorial(4184) = 4184 + factorial(4183)
# factorial(4183) = 4183 + factorial(4182)
# factorial(4182) = 4182 + factorial(4181)
# factorial(4181) = 4181 + factorial(4180)
# factorial(4180) = 4180 + factorial(4179)
# factorial(4179) = 4179 + factorial(4178)
# factorial(4178) = 4178 + factorial(4177)
# factorial(4177) = 4177 + factorial(4176)
# factorial(4176) = 4176 + factorial(4175)
# factorial(4175) = 4175 + factorial(4174)
# factorial(4174) = 4174 + factorial(4173)
# factorial(4173) = 4173 + factorial(4172)
# factorial(4172) = 4172 + factorial(4171)
# factorial(4171) = 4171 + factorial(4170)
# factorial(4170) = 4170 + factorial(4169)
# factorial(4169) = 4169 + factorial(4168)
# factorial(4168) = 4168 + factorial(4167)
# factorial(4167) = 4167 + factorial(4166)
# factorial(4166) = 4166 + factorial(4165)
# factorial(4165) = 4165 + factorial(4164)
# factorial(4164) = 4164 + factorial(4163)
# factorial(4163) = 4163 + factorial(4162)
# factorial(4162) = 4162 + factorial(4161)
# factorial(4161) = 4161 + factorial(4160)
# factorial(4160) = 4160 + factorial(4159)
# factorial(4159) = 4159 + factorial(4158)
# factorial(4158) = 4158 + factorial(4157)
# factorial(4157) = 4157 + factorial(4156)
# factorial(4156) = 4156 + factorial(4155)
# factorial(4155) = 4155 + factorial(4154)
# factorial(4154) = 4154 + factorial(4153)
# factorial(4153) = 4153 + factorial(4152)
# factorial(4152) = 4152 + factorial(4151)
# factorial(4151) = 4151 + factorial(4150)
# factorial(4150) = 4150 + factorial(4149)
# factorial(4149) = 4149 + factorial(4148)
# factorial(4148) = 4148 + factorial(4147)
# factorial(4147) = 4147 + factorial(4146)
# factorial(4146) = 4146 + factorial(4145)
# factorial(4145) = 4145 + factorial(4144)
# factorial(4144) = 4144 + factorial(4143)
# factorial(4143) = 4143 + factorial(4142)
# factorial(4142) = 4142 + factorial(4141)
# factorial(4141) = 4141 + factorial(4140)
# factorial(4140) = 4140 + factorial(4139)
# factorial(4139) = 4139 + factorial(4138)
# factorial(4138) = 4138 + factorial(4137)
# factorial(4137) = 4137 + factorial(4136)
# factorial(4136) = 4136 + factorial(4135)
# factorial(4135) = 4135 + factorial(4134)
# factorial(4134) = 4134 + factorial(4133)
# factorial(4133) = 4133 + factorial(4132)
# factorial(4132) = 4132 + factorial(4131)
# factorial(4131) = 4131 + factorial(4130)
# factorial(4130) = 4130 + factorial(4129)
# factorial(4129) = 4129 + factorial(4128)
# factorial(4128) = 4128 + factorial(4127)
# factorial(4127) = 4127 + factorial(4126)
# factorial(4126) = 4126 + factorial(4125)
# factorial(4125) = 4125 + factorial(4124)
# factorial(4124) = 4124 + factorial(4123)
# factorial(4123) = 4123 + factorial(4122)
# factorial(4122) = 4122 + factorial(4121)
# factorial(4121) = 4121 + factorial(4120)
# factorial(4120) = 4120 + factorial(4119)
# factorial(4119) = 4119 + factorial(4118)
# factorial(4118) = 4118 + factorial(4117)
# factorial(4117) = 4117 + factorial(4116)
# factorial(4116) = 4116 + factorial(4115)
# factorial(4115) = 4115 + factorial(4114)
# factorial(4114) = 4114 + factorial(4113)
# factorial(4113) = 4113 + factorial(4112)
# factorial(4112) = 4112 + factorial(4111)
# factorial(4111) = 4111 + factorial(4110)
# factorial(4110) = 4110 + factorial(4109)
# factorial(4109) = 4109 + factorial(4108)
# factorial(4108) = 4108 + factorial(4107)
# factorial(4107) = 4107 + factorial(4106)
# factorial(4106) = 4106 + factorial(4105)
# factorial(4105) = 4105 + factorial(4104)
# factorial(4104) = 4104 + factorial(4103)
# factorial(4103) = 4103 + factorial(4102)
# factorial(4102) = 4102 + factorial(4101)
# factorial(4101) = 4101 + factorial(4100)
# factorial(4100) = 4100 + factorial(4099)
# factorial(4099) = 4099 + factorial(4098)
# factorial(4098) = 4098 + factorial(4097)
# factorial(4097) = 4097 + factorial(4096)
# factorial(4096) = 4096 + factorial(4095)
# factorial(4095) = 4095 + factorial(4094)
# factorial(4094) = 4094 + factorial(4093)
# factorial(4093) = 4093 + factorial(4092)
# factorial(4092) = 4092 + factorial(4091)
# factorial(4091) = 4091 + factorial(4090)
# factorial(4090) = 4090 + factorial(4089)
# factorial(4089) = 4089 + factorial(4088)
# factorial(4088) = 4088 + factorial(4087)
# factorial(4087) = 4087 + factorial(4086)
# factorial(4086) = 4086 + factorial(4085)
# factorial(4085) = 4085 + factorial(4084)
# factorial(4084) = 4084 + factorial(4083)
# factorial(4083) = 4083 + factorial(4082)
# factorial(4082) = 4082 + factorial(4081)
# factorial(4081) = 4081 + factorial(4080)
# factorial(4080) = 4080 + factorial(4079)
# factorial(4079) = 4079 + factorial(4078)
# factorial(4078) = 4078 + factorial(4077)
# factorial(4077) = 4077 + factorial(4076)
# factorial(4076) = 4076 + factorial(4075)
# factorial(4075) = 4075 + factorial(4074)
# factorial(4074) = 4074 + factorial(4073)
# factorial(4073) = 4073 + factorial(4072)
# factorial(4072) = 4072 + factorial(4071)
# factorial(4071) = 4071 + factorial(4070)
# factorial(4070) = 4070 + factorial(4069)
# factorial(4069) = 4069 + factorial(4068)
# factorial(4068) = 4068 + factorial(4067)
# factorial(4067) = 4067 + factorial(4066)
# factorial(4066) = 4066 + factorial(4065)
# factorial(4065) = 4065 + factorial(4064)
# factorial(4064) = 4064 + factorial(4063)
# factorial(4063) = 4063 + factorial(4062)
# factorial(4062) = 4062 + factorial(4061)
# factorial(4061) = 4061 + factorial(4060)
# factorial(4060) = 4060 + factorial(4059)
# factorial(4059) = 4059 + factorial(4058)
# factorial(4058) = 4058 + factorial(4057)
# factorial(4057) = 4057 + factorial(4056)
# factorial(4056) = 4056 + factorial(4055)
# factorial(4055) = 4055 + factorial(4054)
# factorial(4054) = 4054 + factorial(4053)
# factorial(4053) = 4053 + factorial(4052)
# factorial(4052) = 4052 + factorial(4051)
# factorial(4051) = 4051 + factorial(4050)
# factorial(4050) = 4050 + factorial(4049)
# factorial(4049) = 4049 + factorial(4048)
# factorial(4048) = 4048 + factorial(4047)
# factorial(4047) = 4047 + factorial(4046)
# factorial(4046) = 4046 + factorial(4045)
# factorial(4045) = 4045 + factorial(4044)
# factorial(4044) = 4044 + factorial(4043)
# factorial(4043) = 4043 + factorial(4042)
# factorial(4042) = 4042 + factorial(4041)
# factorial(4041) = 4041 + factorial(4040)
# factorial(4040) = 4040 + factorial(4039)
# factorial(4039) = 4039 + factorial(4038)
# factorial(4038) = 4038 + factorial(4037)
# factorial(4037) = 4037 + factorial(4036)
# factorial(4036) = 4036 + factorial(4035)
# factorial(4035) = 4035 + factorial(4034)
# factorial(4034) = 4034 + factorial(4033)
# factorial(4033) = 4033 + factorial(4032)
# factorial(4032) = 4032 + factorial(4031)
# factorial(4031) = 4031 + factorial(4030)
# factorial(4030) = 4030 + factorial(4029)
# factorial(4029) = 4029 + factorial(4028)
# factorial(4028) = 4028 + factorial(4027)
# factorial(4027) = 4027 + factorial(4026)
# factorial(4026) = 4026 + factorial(4025)
# factorial(4025) = 4025 + factorial(4024)
# factorial(4024) = 4024 + factorial(4023)
# factorial(4023) = 4023 + factorial(4022)
# factorial(4022) = 4022 + factorial(4021)
# factorial(4021) = 4021 + factorial(4020)
# factorial(4020) = 4020 + factorial(4019)
# factorial(4019) = 4019 + factorial(4018)
# factorial(4018) = 4018 + factorial(4017)
# factorial(4017) = 4017 + factorial(4016)
# factorial(4016) = 4016 + factorial(4015)
# factorial(4015) = 4015 + factorial(4014)
# factorial(4014) = 4014 + factorial(4013)
# factorial(4013) = 4013 + factorial(4012)
# factorial(4012) = 4012 + factorial(4011)
# factorial(4011) = 4011 + factorial(4010)
# factorial(4010) = 4010 + factorial(4009)
# factorial(4009) = 4009 + factorial(4008)
# factorial(4008) = 4008 + factorial(4007)
# factorial(4007) = 4007 + factorial(4006)
# factorial(4006) = 4006 + factorial(4005)
# factorial(4005) = 4005 + factorial(4004)
# factorial(4004) = 4004 + factorial(4003)
# factorial(4003) = 4003 + factorial(4002)
# factorial(4002) = 4002 + factorial(4001)
# factorial(4001) = 4001 + factorial(4000)
# factorial(4000) = 4000 + factorial(3999)
# factorial(3999) = 3999 + factorial(3998)
# factorial(3998) = 3998 + factorial(3997)
# factorial(3997) = 3997 + factorial(3996)
# factorial(3996) = 3996 + factorial(3995)
# factorial(3995) = 3995 + factorial(3994)
# factorial(3994) = 3994 + factorial(3993)
# factorial(3993) = 3993 + factorial(3992)
# factorial(3992) = 3992 + factorial(3991)
# factorial(3991) = 3991 + factorial(3990)
# factorial(3990) = 3990 + factorial(3989)
# factorial(3989) = 3989 + factorial(3988)
# factorial(3988) = 3988 + factorial(3987)
# factorial(3987) = 3987 + factorial(3986)
# factorial(3986) = 3986 + factorial(3985)
# factorial(3985) = 3985 + factorial(3984)
# factorial(3984) = 3984 + factorial(3983)
# factorial(3983) = 3983 + factorial(3982)
# factorial(3982) = 3982 + factorial(3981)
# factorial(3981) = 3981 + factorial(3980)
# factorial(3980) = 3980 + factorial(3979)
# factorial(3979) = 3979 + factorial(3978)
# factorial(3978) = 3978 + factorial(3977)
# factorial(3977) = 3977 + factorial(3976)
# factorial(3976) = 3976 + factorial(3975)
# factorial(3975) = 3975 + factorial(3974)
# factorial(3974) = 3974 + factorial(3973)
# factorial(3973) = 3973 + factorial(3972)
# factorial(3972) = 3972 + factorial(3971)
# factorial(3971) = 3971 + factorial(3970)
# factorial(3970) = 3970 + factorial(3969)
# factorial(3969) = 3969 + factorial(3968)
# factorial(3968) = 3968 + factorial(3967)
# factorial(3967) = 3967 + factorial(3966)
# factorial(3966) = 3966 + factorial(3965)
# factorial(3965) = 3965 + factorial(3964)
# factorial(3964) = 3964 + factorial(3963)
# factorial(3963) = 3963 + factorial(3962)
# factorial(3962) = 3962 + factorial(3961)
# factorial(3961) = 3961 + factorial(3960)
# factorial(3960) = 3960 + factorial(3959)
# factorial(3959) = 3959 + factorial(3958)
# factorial(3958) = 3958 + factorial(3957)
# factorial(3957) = 3957 + factorial(3956)
# factorial(3956) = 3956 + factorial(3955)
# factorial(3955) = 3955 + factorial(3954)
# factorial(3954) = 3954 + factorial(3953)
# factorial(3953) = 3953 + factorial(3952)
# factorial(3952) = 3952 + factorial(3951)
# factorial(3951) = 3951 + factorial(3950)
# factorial(3950) = 3950 + factorial(3949)
# factorial(3949) = 3949 + factorial(3948)
# factorial(3948) = 3948 + factorial(3947)
# factorial(3947) = 3947 + factorial(3946)
# factorial(3946) = 3946 + factorial(3945)
# factorial(3945) = 3945 + factorial(3944)
# factorial(3944) = 3944 + factorial(3943)
# factorial(3943) = 3943 + factorial(3942)
# factorial(3942) = 3942 + factorial(3941)
# factorial(3941) = 3941 + factorial(3940)
# factorial(3940) = 3940 + factorial(3939)
# factorial(3939) = 3939 + factorial(3938)
# factorial(3938) = 3938 + factorial(3937)
# factorial(3937) = 3937 + factorial(3936)
# factorial(3936) = 3936 + factorial(3935)
# factorial(3935) = 3935 + factorial(3934)
# factorial(3934) = 3934 + factorial(3933)
# factorial(3933) = 3933 + factorial(3932)
# factorial(3932) = 3932 + factorial(3931)
# factorial(3931) = 3931 + factorial(3930)
# factorial(3930) = 3930 + factorial(3929)
# factorial(3929) = 3929 + factorial(3928)
# factorial(3928) = 3928 + factorial(3927)
# factorial(3927) = 3927 + factorial(3926)
# factorial(3926) = 3926 + factorial(3925)
# factorial(3925) = 3925 + factorial(3924)
# factorial(3924) = 3924 + factorial(3923)
# factorial(3923) = 3923 + factorial(3922)
# factorial(3922) = 3922 + factorial(3921)
# factorial(3921) = 3921 + factorial(3920)
# factorial(3920) = 3920 + factorial(3919)
# factorial(3919) = 3919 + factorial(3918)
# factorial(3918) = 3918 + factorial(3917)
# factorial(3917) = 3917 + factorial(3916)
# factorial(3916) = 3916 + factorial(3915)
# factorial(3915) = 3915 + factorial(3914)
# factorial(3914) = 3914 + factorial(3913)
# factorial(3913) = 3913 + factorial(3912)
# factorial(3912) = 3912 + factorial(3911)
# factorial(3911) = 3911 + factorial(3910)
# factorial(3910) = 3910 + factorial(3909)
# factorial(3909) = 3909 + factorial(3908)
# factorial(3908) = 3908 + factorial(3907)
# factorial(3907) = 3907 + factorial(3906)
# factorial(3906) = 3906 + factorial(3905)
# factorial(3905) = 3905 + factorial(3904)
# factorial(3904) = 3904 + factorial(3903)
# factorial(3903) = 3903 + factorial(3902)
# factorial(3902) = 3902 + factorial(3901)
# factorial(3901) = 3901 + factorial(3900)
# factorial(3900) = 3900 + factorial(3899)
# factorial(3899) = 3899 + factorial(3898)
# factorial(3898) = 3898 + factorial(3897)
# factorial(3897) = 3897 + factorial(3896)
# factorial(3896) = 3896 + factorial(3895)
# factorial(3895) = 3895 + factorial(3894)
# factorial(3894) = 3894 + factorial(3893)
# factorial(3893) = 3893 + factorial(3892)
# factorial(3892) = 3892 + factorial(3891)
# factorial(3891) = 3891 + factorial(3890)
# factorial(3890) = 3890 + factorial(3889)
# factorial(3889) = 3889 + factorial(3888)
# factorial(3888) = 3888 + factorial(3887)
# factorial(3887) = 3887 + factorial(3886)
# factorial(3886) = 3886 + factorial(3885)
# factorial(3885) = 3885 + factorial(3884)
# factorial(3884) = 3884 + factorial(3883)
# factorial(3883) = 3883 + factorial(3882)
# factorial(3882) = 3882 + factorial(3881)
# factorial(3881) = 3881 + factorial(3880)
# factorial(3880) = 3880 + factorial(3879)
# factorial(3879) = 3879 + factorial(3878)
# factorial(3878) = 3878 + factorial(3877)
# factorial(3877) = 3877 + factorial(3876)
# factorial(3876) = 3876 + factorial(3875)
# factorial(3875) = 3875 + factorial(3874)
# factorial(3874) = 3874 + factorial(3873)
# factorial(3873) = 3873 + factorial(3872)
# factorial(3872) = 3872 + factorial(3871)
# factorial(3871) = 3871 + factorial(3870)
# factorial(3870) = 3870 + factorial(3869)
# factorial(3869) = 3869 + factorial(3868)
# factorial(3868) = 3868 + factorial(3867)
# factorial(3867) = 3867 + factorial(3866)
# factorial(3866) = 3866 + factorial(3865)
# factorial(3865) = 3865 + factorial(3864)
# factorial(3864) = 3864 + factorial(3863)
# factorial(3863) = 3863 + factorial(3862)
# factorial(3862) = 3862 + factorial(3861)
# factorial(3861) = 3861 + factorial(3860)
# factorial(3860) = 3860 + factorial(3859)
# factorial(3859) = 3859 + factorial(3858)
# factorial(3858) = 3858 + factorial(3857)
# factorial(3857) = 3857 + factorial(3856)
# factorial(3856) = 3856 + factorial(3855)
# factorial(3855) = 3855 + factorial(3854)
# factorial(3854) = 3854 + factorial(3853)
# factorial(3853) = 3853 + factorial(3852)
# factorial(3852) = 3852 + factorial(3851)
# factorial(3851) = 3851 + factorial(3850)
# factorial(3850) = 3850 + factorial(3849)
# factorial(3849) = 3849 + factorial(3848)
# factorial(3848) = 3848 + factorial(3847)
# factorial(3847) = 3847 + factorial(3846)
# factorial(3846) = 3846 + factorial(3845)
# factorial(3845) = 3845 + factorial(3844)
# factorial(3844) = 3844 + factorial(3843)
# factorial(3843) = 3843 + factorial(3842)
# factorial(3842) = 3842 + factorial(3841)
# factorial(3841) = 3841 + factorial(3840)
# factorial(3840) = 3840 + factorial(3839)
# factorial(3839) = 3839 + factorial(3838)
# factorial(3838) = 3838 + factorial(3837)
# factorial(3837) = 3837 + factorial(3836)
# factorial(3836) = 3836 + factorial(3835)
# factorial(3835) = 3835 + factorial(3834)
# factorial(3834) = 3834 + factorial(3833)
# factorial(3833) = 3833 + factorial(3832)
# factorial(3832) = 3832 + factorial(3831)
# factorial(3831) = 3831 + factorial(3830)
# ...
# factorial(2414) = 2414 + factorial(2413)
# factorial(2413) = 2413 + factorial(2412)
# factorial(2412) = 2412 + factorial(2411)
# factorial(2411) = 2411 + factorial(2410)
# factorial(2410) = 2410 + factorial(2409)
# factorial(2409) = 2409 + factorial(2408)
# factorial(2408) = 2408 + factorial(2407)
# factorial(2407) = 2407 + factorial(2406)
# factorial(2406) = 2406 + factorial(2405)
# factorial(2405) = 2405 + factorial(2404)
# factorial(2404) = 2404 + factorial(2403)
# factorial(2403) = 2403 + factorial(2402)
# factorial(2402) = 2402 + factorial(2401)
# factorial(2401) = 2401 + factorial(2400)
# factorial(2400) = 2400 + factorial(2399)
# factorial(2399) = 2399 + factorial(2398)
# factorial(2398) = 2398 + factorial(2397)
# factorial(2397) = 2397 + factorial(2396)
# factorial(2396) = 2396 + factorial(2395)
# factorial(2395) = 2395 + factorial(2394)
# factorial(2394) = 2394 + factorial(2393)
# factorial(2393) = 2393 + factorial(2392)
# factorial(2392) = 2392 + factorial(2391)
# factorial(2391) = 2391 + factorial(2390)
# factorial(2390) = 2390 + factorial(2389)
# factorial(2389) = 2389 + factorial(2388)
# factorial(2388) = 2388 + factorial(2387)
# factorial(2387) = 2387 + factorial(2386)
# factorial(2386) = 2386 + factorial(2385)
# factorial(2385) = 2385 + factorial(2384)
# factorial(2384) = 2384 + factorial(2383)
# factorial(2383) = 2383 + factorial(2382)
# factorial(2382) = 2382 + factorial(2381)
# factorial(2381) = 2381 + factorial(2380)
# factorial(2380) = 2380 + factorial(2379)
# factorial(2379) = 2379 + factorial(2378)
# factorial(2378) = 2378 + factorial(2377)
# factorial(2377) = 2377 + factorial(2376)
# factorial(2376) = 2376 + factorial(2375)
# factorial(2375) = 2375 + factorial(2374)
# factorial(2374) = 2374 + factorial(2373)
# factorial(2373) = 2373 + factorial(2372)
# factorial(2372) = 2372 + factorial(2371)
# factorial(2371) = 2371 + factorial(2370)
# factorial(2370) = 2370 + factorial(2369)
# factorial(2369) = 2369 + factorial(2368)
# factorial(2368) = 2368 + factorial(2367)
# factorial(2367) = 2367 + factorial(2366)
# factorial(2366) = 2366 + factorial(2365)
# factorial(2365) = 2365 + factorial(2364)
# factorial(2364) = 2364 + factorial(2363)
# factorial(2363) = 2363 + factorial(2362)
# factorial(2362) = 2362 + factorial(2361)
# factorial(2361) = 2361 + factorial(2360)
# factorial(2360) = 2360 + factorial(2359)
# factorial(2359) = 2359 + factorial(2358)
# factorial(2358) = 2358 + factorial(2357)
# factorial(2357) = 2357 + factorial(2356)
# factorial(2356) = 2356 + factorial(2355)
# factorial(2355) = 2355 + factorial(2354)
# factorial(2354) = 2354 + factorial(2353)
# factorial(2353) = 2353 + factorial(2352)
# factorial(2352) = 2352 + factorial(2351)
# factorial(2351) = 2351 + factorial(2350)
# factorial(2350) = 2350 + factorial(2349)
# factorial(2349) = 2349 + factorial(2348)
# factorial(2348) = 2348 + factorial(2347)
# factorial(2347) = 2347 + factorial(2346)
# factorial(2346) = 2346 + factorial(2345)
# factorial(2345) = 2345 + factorial(2344)
# factorial(2344) = 2344 + factorial(2343)
# factorial(2343) = 2343 + factorial(2342)
# factorial(2342) = 2342 + factorial(2341)
# factorial(2341) = 2341 + factorial(2340)
# factorial(2340) = 2340 + factorial(2339)
# factorial(2339) = 2339 + factorial(2338)
# factorial(2338) = 2338 + factorial(2337)
# factorial(2337) = 2337 + factorial(2336)
# factorial(2336) = 2336 + factorial(2335)
# factorial(2335) = 2335 + factorial(2334)
# factorial(2334) = 2334 + factorial(2333)
# factorial(2333) = 2333 + factorial(2332)
# factorial(2332) = 2332 + factorial(2331)
# factorial(2331) = 2331 + factorial(2330)
# factorial(2330) = 2330 + factorial(2329)
# factorial(2329) = 2329 + factorial(2328)
# factorial(2328) = 2328 + factorial(2327)
# factorial(2327) = 2327 + factorial(2326)
# factorial(2326) = 2326 + factorial(2325)
# factorial(2325) = 2325 + factorial(2324)
# factorial(2324) = 2324 + factorial(2323)
# factorial(2323) = 2323 + factorial(2322)
# factorial(2322) = 2322 + factorial(2321)
# factorial(2321) = 2321 + factorial(2320)
# factorial(2320) = 2320 + factorial(2319)
# factorial(2319) = 2319 + factorial(2318)
# factorial(2318) = 2318 + factorial(2317)
# factorial(2317) = 2317 + factorial(2316)
# factorial(2316) = 2316 + factorial(2315)
# factorial(2315) = 2315 + factorial(2314)
# factorial(2314) = 2314 + factorial(2313)
# factorial(2313) = 2313 + factorial(2312)
# factorial(2312) = 2312 + factorial(2311)
# factorial(2311) = 2311 + factorial(2310)
# factorial(2310) = 2310 + factorial(2309)
# factorial(2309) = 2309 + factorial(2308)
# factorial(2308) = 2308 + factorial(2307)
# factorial(2307) = 2307 + factorial(2306)
# factorial(2306) = 2306 + factorial(2305)
# factorial(2305) = 2305 + factorial(2304)
# factorial(2304) = 2304 + factorial(2303)
# factorial(2303) = 2303 + factorial(2302)
# factorial(2302) = 2302 + factorial(2301)
# factorial(2301) = 2301 + factorial(2300)
# factorial(2300) = 2300 + factorial(2299)
# factorial(2299) = 2299 + factorial(2298)
# factorial(2298) = 2298 + factorial(2297)
# factorial(2297) = 2297 + factorial(2296)
# factorial(2296) = 2296 + factorial(2295)
# factorial(2295) = 2295 + factorial(2294)
# factorial(2294) = 2294 + factorial(2293)
# factorial(2293) = 2293 + factorial(2292)
# factorial(2292) = 2292 + factorial(2291)
# factorial(2291) = 2291 + factorial(2290)
# factorial(2290) = 2290 + factorial(2289)
# factorial(2289) = 2289 + factorial(2288)
# factorial(2288) = 2288 + factorial(2287)
# factorial(2287) = 2287 + factorial(2286)
# factorial(2286) = 2286 + factorial(2285)
# factorial(2285) = 2285 + factorial(2284)
# factorial(2284) = 2284 + factorial(2283)
# factorial(2283) = 2283 + factorial(2282)
# factorial(2282) = 2282 + factorial(2281)
# factorial(2281) = 2281 + factorial(2280)
# factorial(2280) = 2280 + factorial(2279)
# factorial(2279) = 2279 + factorial(2278)
# factorial(2278) = 2278 + factorial(2277)
# factorial(2277) = 2277 + factorial(2276)
# factorial(2276) = 2276 + factorial(2275)
# factorial(2275) = 2275 + factorial(2274)
# factorial(2274) = 2274 + factorial(2273)
# factorial(2273) = 2273 + factorial(2272)
# factorial(2272) = 2272 + factorial(2271)
# factorial(2271) = 2271 + factorial(2270)
# factorial(2270) = 2270 + factorial(2269)
# factorial(2269) = 2269 + factorial(2268)
# factorial(2268) = 2268 + factorial(2267)
# factorial(2267) = 2267 + factorial(2266)
# factorial(2266) = 2266 + factorial(2265)
# factorial(2265) = 2265 + factorial(2264)
# factorial(2264) = 2264 + factorial(2263)
# factorial(2263) = 2263 + factorial(2262)
# factorial(2262) = 2262 + factorial(2261)
# factorial(2261) = 2261 + factorial(2260)
# factorial(2260) = 2260 + factorial(2259)
# factorial(2259) = 2259 + factorial(2258)
# factorial(2258) = 2258 + factorial(2257)
# factorial(2257) = 2257 + factorial(2256)
# factorial(2256) = 2256 + factorial(2255)
# factorial(2255) = 2255 + factorial(2254)
# factorial(2254) = 2254 + factorial(2253)
# factorial(2253) = 2253 + factorial(2252)
# factorial(2252) = 2252 + factorial(2251)
# factorial(2251) = 2251 + factorial(2250)
# factorial(2250) = 2250 + factorial(2249)
# factorial(2249) = 2249 + factorial(2248)
# factorial(2248) = 2248 + factorial(2247)
# factorial(2247) = 2247 + factorial(2246)
# factorial(2246) = 2246 + factorial(2245)
# factorial(2245) = 2245 + factorial(2244)
# factorial(2244) = 2244 + factorial(2243)
# factorial(2243) = 2243 + factorial(2242)
# factorial(2242) = 2242 + factorial(2241)
# factorial(2241) = 2241 + factorial(2240)
# factorial(2240) = 2240 + factorial(2239)
# factorial(2239) = 2239 + factorial(2238)
# factorial(2238) = 2238 + factorial(2237)
# factorial(2237) = 2237 + factorial(2236)
# factorial(2236) = 2236 + factorial(2235)
# factorial(2235) = 2235 + factorial(2234)
# factorial(2234) = 2234 + factorial(2233)
# factorial(2233) = 2233 + factorial(2232)
# factorial(2232) = 2232 + factorial(2231)
# factorial(2231) = 2231 + factorial(2230)
# factorial(2230) = 2230 + factorial(2229)
# factorial(2229) = 2229 + factorial(2228)
# factorial(2228) = 2228 + factorial(2227)
# factorial(2227) = 2227 + factorial(2226)
# factorial(2226) = 2226 + factorial(2225)
# factorial(2225) = 2225 + factorial(2224)
# factorial(2224) = 2224 + factorial(2223)
# factorial(2223) = 2223 + factorial(2222)
# factorial(2222) = 2222 + factorial(2221)
# factorial(2221) = 2221 + factorial(2220)
# factorial(2220) = 2220 + factorial(2219)
# factorial(2219) = 2219 + factorial(2218)
# factorial(2218) = 2218 + factorial(2217)
# factorial(2217) = 2217 + factorial(2216)
# factorial(2216) = 2216 + factorial(2215)
# factorial(2215) = 2215 + factorial(2214)
# factorial(2214) = 2214 + factorial(2213)
# factorial(2213) = 2213 + factorial(2212)
# factorial(2212) = 2212 + factorial(2211)
# factorial(2211) = 2211 + factorial(2210)
# factorial(2210) = 2210 + factorial(2209)
# factorial(2209) = 2209 + factorial(2208)
# factorial(2208) = 2208 + factorial(2207)
# factorial(2207) = 2207 + factorial(2206)
# factorial(2206) = 2206 + factorial(2205)
# factorial(2205) = 2205 + factorial(2204)
# factorial(2204) = 2204 + factorial(2203)
# factorial(2203) = 2203 + factorial(2202)
# factorial(2202) = 2202 + factorial(2201)
# factorial(2201) = 2201 + factorial(2200)
# factorial(2200) = 2200 + factorial(2199)
# factorial(2199) = 2199 + factorial(2198)
# factorial(2198) = 2198 + factorial(2197)
# factorial(2197) = 2197 + factorial(2196)
# factorial(2196) = 2196 + factorial(2195)
# factorial(2195) = 2195 + factorial(2194)
# factorial(2194) = 2194 + factorial(2193)
# factorial(2193) = 2193 + factorial(2192)
# factorial(2192) = 2192 + factorial(2191)
# factorial(2191) = 2191 + factorial(2190)
# factorial(2190) = 2190 + factorial(2189)
# factorial(2189) = 2189 + factorial(2188)
# factorial(2188) = 2188 + factorial(2187)
# factorial(2187) = 2187 + factorial(2186)
# factorial(2186) = 2186 + factorial(2185)
# factorial(2185) = 2185 + factorial(2184)
# factorial(2184) = 2184 + factorial(2183)
# factorial(2183) = 2183 + factorial(2182)
# factorial(2182) = 2182 + factorial(2181)
# factorial(2181) = 2181 + factorial(2180)
# factorial(2180) = 2180 + factorial(2179)
# factorial(2179) = 2179 + factorial(2178)
# factorial(2178) = 2178 + factorial(2177)
# factorial(2177) = 2177 + factorial(2176)
# factorial(2176) = 2176 + factorial(2175)
# factorial(2175) = 2175 + factorial(2174)
# factorial(2174) = 2174 + factorial(2173)
# factorial(2173) = 2173 + factorial(2172)
# factorial(2172) = 2172 + factorial(2171)
# factorial(2171) = 2171 + factorial(2170)
# factorial(2170) = 2170 + factorial(2169)
# factorial(2169) = 2169 + factorial(2168)
# factorial(2168) = 2168 + factorial(2167)
# factorial(2167) = 2167 + factorial(2166)
# factorial(2166) = 2166 + factorial(2165)
# factorial(2165) = 2165 + factorial(2164)
# factorial(2164) = 2164 + factorial(2163)
# factorial(2163) = 2163 + factorial(2162)
# factorial(2162) = 2162 + factorial(2161)
# factorial(2161) = 2161 + factorial(2160)
# factorial(2160) = 2160 + factorial(2159)
# factorial(2159) = 2159 + factorial(2158)
# factorial(2158) = 2158 + factorial(2157)
# factorial(2157) = 2157 + factorial(2156)
# factorial(2156) = 2156 + factorial(2155)
# factorial(2155) = 2155 + factorial(2154)
# factorial(2154) = 2154 + factorial(2153)
# factorial(2153) = 2153 + factorial(2152)
# factorial(2152) = 2152 + factorial(2151)
# factorial(2151) = 2151 + factorial(2150)
# factorial(2150) = 2150 + factorial(2149)
# factorial(2149) = 2149 + factorial(2148)
# factorial(2148) = 2148 + factorial(2147)
# factorial(2147) = 2147 + factorial(2146)
# factorial(2146) = 2146 + factorial(2145)
# factorial(2145) = 2145 + factorial(2144)
# factorial(2144) = 2144 + factorial(2143)
# factorial(2143) = 2143 + factorial(2142)
# factorial(2142) = 2142 + factorial(2141)
# factorial(2141) = 2141 + factorial(2140)
# factorial(2140) = 2140 + factorial(2139)
# factorial(2139) = 2139 + factorial(2138)
# factorial(2138) = 2138 + factorial(2137)
# factorial(2137) = 2137 + factorial(2136)
# factorial(2136) = 2136 + factorial(2135)
# factorial(2135) = 2135 + factorial(2134)
# factorial(2134) = 2134 + factorial(2133)
# factorial(2133) = 2133 + factorial(2132)
# factorial(2132) = 2132 + factorial(2131)
# factorial(2131) = 2131 + factorial(2130)
# factorial(2130) = 2130 + factorial(2129)
# factorial(2129) = 2129 + factorial(2128)
# factorial(2128) = 2128 + factorial(2127)
# factorial(2127) = 2127 + factorial(2126)
# factorial(2126) = 2126 + factorial(2125)
# factorial(2125) = 2125 + factorial(2124)
# factorial(2124) = 2124 + factorial(2123)
# factorial(2123) = 2123 + factorial(2122)
# factorial(2122) = 2122 + factorial(2121)
# factorial(2121) = 2121 + factorial(2120)
# factorial(2120) = 2120 + factorial(2119)
# factorial(2119) = 2119 + factorial(2118)
# factorial(2118) = 2118 + factorial(2117)
# factorial(2117) = 2117 + factorial(2116)
# factorial(2116) = 2116 + factorial(2115)
# factorial(2115) = 2115 + factorial(2114)
# factorial(2114) = 2114 + factorial(2113)
# factorial(2113) = 2113 + factorial(2112)
# factorial(2112) = 2112 + factorial(2111)
# factorial(2111) = 2111 + factorial(2110)
# factorial(2110) = 2110 + factorial(2109)
# factorial(2109) = 2109 + factorial(2108)
# factorial(2108) = 2108 + factorial(2107)
# factorial(2107) = 2107 + factorial(2106)
# factorial(2106) = 2106 + factorial(2105)
# factorial(2105) = 2105 + factorial(2104)
# factorial(2104) = 2104 + factorial(2103)
# factorial(2103) = 2103 + factorial(2102)
# factorial(2102) = 2102 + factorial(2101)
# factorial(2101) = 2101 + factorial(2100)
# factorial(2100) = 2100 + factorial(2099)
# factorial(2099) = 2099 + factorial(2098)
# factorial(2098) = 2098 + factorial(2097)
# factorial(2097) = 2097 + factorial(2096)
# factorial(2096) = 2096 + factorial(2095)
# factorial(2095) = 2095 + factorial(2094)
# factorial(2094) = 2094 + factorial(2093)
# factorial(2093) = 2093 + factorial(2092)
# factorial(2092) = 2092 + factorial(2091)
# factorial(2091) = 2091 + factorial(2090)
# factorial(2090) = 2090 + factorial(2089)
# factorial(2089) = 2089 + factorial(2088)
# factorial(2088) = 2088 + factorial(2087)
# factorial(2087) = 2087 + factorial(2086)
# factorial(2086) = 2086 + factorial(2085)
# factorial(2085) = 2085 + factorial(2084)
# factorial(2084) = 2084 + factorial(2083)
# factorial(2083) = 2083 + factorial(2082)
# factorial(2082) = 2082 + factorial(2081)
# factorial(2081) = 2081 + factorial(2080)
# factorial(2080) = 2080 + factorial(2079)
# factorial(2079) = 2079 + factorial(2078)
# factorial(2078) = 2078 + factorial(2077)
# factorial(2077) = 2077 + factorial(2076)
# factorial(2076) = 2076 + factorial(2075)
# factorial(2075) = 2075 + factorial(2074)
# factorial(2074) = 2074 + factorial(2073)
# factorial(2073) = 2073 + factorial(2072)
# factorial(2072) = 2072 + factorial(2071)
# factorial(2071) = 2071 + factorial(2070)
# factorial(2070) = 2070 + factorial(2069)
# factorial(2069) = 2069 + factorial(2068)
# factorial(2068) = 2068 + factorial(2067)
# factorial(2067) = 2067 + factorial(2066)
# factorial(2066) = 2066 + factorial(2065)
# factorial(2065) = 2065 + factorial(2064)
# factorial(2064) = 2064 + factorial(2063)
# factorial(2063) = 2063 + factorial(2062)
# factorial(2062) = 2062 + factorial(2061)
# factorial(2061) = 2061 + factorial(2060)
# factorial(2060) = 2060 + factorial(2059)
# factorial(2059) = 2059 + factorial(2058)
# factorial(2058) = 2058 + factorial(2057)
# factorial(2057) = 2057 + factorial(2056)
# factorial(2056) = 2056 + factorial(2055)
# factorial(2055) = 2055 + factorial(2054)
# factorial(2054) = 2054 + factorial(2053)
# factorial(2053) = 2053 + factorial(2052)
# factorial(2052) = 2052 + factorial(2051)
# factorial(2051) = 2051 + factorial(2050)
# factorial(2050) = 2050 + factorial(2049)
# factorial(2049) = 2049 + factorial(2048)
# factorial(2048) = 2048 + factorial(2047)
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-71-f090da229b9c> in <module>
#       7         print(f"factorial({num}) = {num} + factorial({num-1})")
#       8         return num * factorial(num-1)
# ----> 9 factorial(5000)
#      10
#      11
#
# <ipython-input-71-f090da229b9c> in factorial(num)
#       6     else:
#       7         print(f"factorial({num}) = {num} + factorial({num-1})")
# ----> 8         return num * factorial(num-1)
#       9 factorial(5000)
#      10
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-71-f090da229b9c> in factorial(num)
#       6     else:
#       7         print(f"factorial({num}) = {num} + factorial({num-1})")
# ----> 8         return num * factorial(num-1)
#       9 factorial(5000)
#      10
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# #### In-Class Exercise #5 <br>
# <p>Write a recursive function that subtracts all numbers to the argument given.</p>

# %%
n = 5
def subtract(num):
    if num <= 1:
        return 1
    else:
        print(f"{num} - subtract({num-1})")
        return num - subtract(num-1)
subtract(5)    #fibunacci sequence
# Out:
# 5 - subtract(4)
# 4 - subtract(3)
# 3 - subtract(2)
# 2 - subtract(1)
# 3

# %% [markdown]
# ## Generators <br>
# <p>Generators are a type of iterable, like lists or tuples. They do not allow indexing, but they can still be iterated through with for loops. They are created using functions and the yield statement.</p>

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
def my_range(n):
    for i in range(n):
        yield i
        
list(my_range(5))        # yield creates a list -- generator
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# #### Yield Keyword <br>
# <p>The yield keyword denotes a generator, it doesn't return so it won't leave the function and reset all variables in the function scope, instead it yields the number back to the caller.</p>

# %%
def range_squared(start, stop, step=1):
    while start > stop:
        yield start **2
        start -= step
for num in range_squared(0,10,1):
    print(num)

# %% [markdown]
# #### Infinite Generator

# %%
# bad, never create infinite loops

# %% [markdown]
# #### In-Class Exercise #6 <br>
# <p>Create a generator that takes a number argument and yields that number squared, then prints each number squared until zero is reached.</p>

# %%
def my_range(start, stop, step=1):
    while start < stop:
        yield start
        start *= step
print(list(my_range(1,5,1)))

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise #1 <br>
# <p>Filter out all of the empty strings from the list below</p>
#
# `Output: ['Argentina', 'San Diego', 'Boston', 'New York']`

# %%
places = [" ","Argentina", " ", "San Diego",""," ","","Boston","New York"]

def empty_strings(names):
    if names == ", ":
        return True
    else:
        return False
new_string = filter(empty_strings, places)    
list(new_string)
# Out:
# []

# %% [markdown]
# ### Exercise #2 <br>
# <p>Write an anonymous function that sorts this list by the last name...<br><b>Hint: Use the ".sort()" method and access the key"</b></p>
#
# `Output: ['Victor aNisimov', 'Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'David hassELHOFF']`

# %%
# CAP matters
author = ["Joel Carter", "Victor aNisimov", "Andrew P. Garfield","David hassELHOFF","Gary A.J. Bernstein"]
author.sort(key=lambda name: name.split(" ")[-1].lower())
print(author)
# Out:
# ['Gary A.J. Bernstein', 'Joel Carter', 'Andrew P. Garfield', 'Victor aNisimov', 'David hassELHOFF']

# %% [markdown]
# ### Exercise #3 <br>
# <p>Convert the list below from Celsius to Farhenheit, using the map function with a lambda...</p>
#
# `Output: [('Nashua', 89.6), ('Boston', 53.6), ('Los Angelos', 111.2), ('Miami', 84.2)]
# `

# %%
# F = (9/5)*C + 32
places = [('Nashua',32),("Boston",12),("Los Angelos",44),("Miami",29)]

Fahrenheit = list(map(lambda x: (9/5)*x[1] + 32, places))
print(Fahrenheit)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-99dd1e1513da> in <module>
#       2 places = [('Nashua',32),("Boston",12),("Los Angelos",44),("Miami",29)]
#       3
# ----> 4 Fahrenheit = list(map(lambda x: (9/5)*x[1] + 32, places.split().lower()))
#       5 print(Fahrenheit)
#       6
#
# AttributeError: 'list' object has no attribute 'split'

# %% [markdown]
# ### Exercise #4 <br>
# <p>Write a recursion function to perform the fibonacci sequence up to the number passed in.</p>
#
# `Output for fib(5) =>
# Iteration 0: 1
# Iteration 1: 1
# Iteration 2: 2
# Iteration 3: 3
# Iteration 4: 5
# Iteration 5: 8`

# %%
n = 5
def fib(num):
    # set base case
    if num <= 5:
        print("add_nums(5)=1")
        return num
    else:
        print(f"add_num({num}) = {num} + add_nums({num -1})")
        return num + add_nums(num-1)
fib(5)
# Out:
# add_nums(5)=1
# 5

# %%
# Out:
# 5 - subtract(4)
# 4 - subtract(3)
# 3 - subtract(2)
# 2 - subtract(1)
# 3
